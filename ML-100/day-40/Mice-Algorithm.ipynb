# %%
import numpy as np 
import pandas as pd

from sklearn.linear_model import LinearRegression

# %%
df = np.round(pd.read_csv('50_Startups.csv')[['R&D Spend','Administration','Marketing Spend','Profit']]/10000)

# %%
np.random.seed(9)

# %%
df = df.sample(5)

# %%
df
# Out:
#     R&D Spend  Administration  Marketing Spend  Profit
# 21        8.0            15.0             30.0    11.0
# 37        4.0             5.0             20.0     9.0
# 2        15.0            10.0             41.0    19.0
# 14       12.0            16.0             26.0    13.0
# 44        2.0            15.0              3.0     7.0

# %%
df = df.iloc[:,0:3].copy()
df
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21        8.0            15.0             30.0
# 37        4.0             5.0             20.0
# 2        15.0            10.0             41.0
# 14       12.0            16.0             26.0
# 44        2.0            15.0              3.0

# %%
df.iloc[1,0] = np.nan
df.iloc[3,1] = np.nan
df.iloc[4,2] = np.nan

# %%
df.head()
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21        8.0            15.0             30.0
# 37        NaN             5.0             20.0
# 2        15.0            10.0             41.0
# 14       12.0             NaN             26.0
# 44        2.0            15.0              NaN

# %%
# step 1 - Impute all missing values withmean of respective col

df0 = pd.DataFrame()

df0['R&D Spend'] = df['R&D Spend'].fillna(df['R&D Spend'].mean())
df0['Administration'] = df['Administration'].fillna(df['Administration'].mean())
df0['Marketing Spend'] = df['Marketing Spend'].fillna(df['Administration'].mean())

# %%
df0
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21       8.00           15.00            30.00
# 37       9.25            5.00            20.00
# 2       15.00           10.00            41.00
# 14      12.00           11.25            26.00
# 44       2.00           15.00            11.25

# %% [markdown]
# ## remove the col 1 impute values

# %%
df1 = df0.copy()
df1.iloc[1,0] = np.nan
df1
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21        8.0           15.00            30.00
# 37        NaN            5.00            20.00
# 2        15.0           10.00            41.00
# 14       12.0           11.25            26.00
# 44        2.0           15.00            11.25

# %%
# use first 3 rows to build a model and use the last for prediction

X = df1.iloc[[0,2,3,4],1:3]
X
# Out:
#     Administration  Marketing Spend
# 21           15.00            30.00
# 2            10.00            41.00
# 14           11.25            26.00
# 44           15.00            11.25

# %%
y = df1.iloc[[0,2,3,4],0]
y
# Out:
# 21     8.0
# 2     15.0
# 14    12.0
# 44     2.0
# Name: R&D Spend, dtype: float64

# %%
lr = LinearRegression()
lr.fit(X.values,y)
lr.predict(df1.iloc[1,1:].values.reshape(1,2))
# Out:
# array([16.35889241])

# %%
df1.iloc[1,0] = 16.35

# %%
df1
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21       8.00           15.00            30.00
# 37      16.35            5.00            20.00
# 2       15.00           10.00            41.00
# 14      12.00           11.25            26.00
# 44       2.00           15.00            11.25

# %% [markdown]
# ## remove the col 2 impute values

# %%
df1.iloc[3,1] = np.nan

df1
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21       8.00            15.0            30.00
# 37      16.35             5.0            20.00
# 2       15.00            10.0            41.00
# 14      12.00             NaN            26.00
# 44       2.00            15.0            11.25

# %%
# use last 3 rows to build a model and use the first for prediction
X = df1.iloc[[0,1,2,4],[0,2]]
X
# Out:
#     R&D Spend  Marketing Spend
# 21       8.00            30.00
# 37      16.35            20.00
# 2       15.00            41.00
# 44       2.00            11.25

# %%
y = df.iloc[[0,1,2,4],1]
y
# Out:
# 21    15.0
# 37     5.0
# 2     10.0
# 44    15.0
# Name: Administration, dtype: float64

# %%
lr = LinearRegression()
lr.fit(X.values,y)
lr.predict(df1.iloc[3,[0,2]].values.reshape(1,2))
# Out:
# array([9.90287508])

# %%
df1.iloc[3,1] =9.90
df1
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21       8.00            15.0            30.00
# 37      16.35             5.0            20.00
# 2       15.00            10.0            41.00
# 14      12.00             9.9            26.00
# 44       2.00            15.0            11.25

# %% [markdown]
# ## remove the col 3 impute value

# %%
df1.iloc[4,-1] = np.nan

df1
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21       8.00            15.0             30.0
# 37      16.35             5.0             20.0
# 2       15.00            10.0             41.0
# 14      12.00             9.9             26.0
# 44       2.00            15.0              NaN

# %%
# use last 3 rows to build a model ans use for prediction

X = df1.iloc[0:4,0:2]
X
# Out:
#     R&D Spend  Administration
# 21       8.00            15.0
# 37      16.35             5.0
# 2       15.00            10.0
# 14      12.00             9.9

# %%
y = df1.iloc[0:4,-1]
y
# Out:
# 21    30.0
# 37    20.0
# 2     41.0
# 14    26.0
# Name: Marketing Spend, dtype: float64

# %%
lr = LinearRegression()
lr.fit(X.values,y)
lr.predict(df1.iloc[4,0:2].values.reshape(1,2))
# Out:
# array([-0.96279304])

# %%
df1.iloc[4,-1] = -0.96

# %%
df1
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21       8.00            15.0            30.00
# 37      16.35             5.0            20.00
# 2       15.00            10.0            41.00
# 14      12.00             9.9            26.00
# 44       2.00            15.0            -0.96

# %% [markdown]
# ## Substraction 0th iteration from 1st iteration

# %%
df1 - df0
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21        0.0            0.00             0.00
# 37        7.1            0.00             0.00
# 2         0.0            0.00             0.00
# 14        0.0           -1.35             0.00
# 44        0.0            0.00           -12.21

# %%
df2 = df1.copy()

df2.iloc[1,0] = np.nan

# %%
X = df2.iloc[[0,2,3,4],1:3]
y = df2.iloc[[0,2,3,4],0]

# %%
lr = LinearRegression()
lr.fit(X.values,y)
lr.predict(df2.iloc[1,1:].values.reshape(1,2))
# Out:
# array([14.91676157])

# %%
df2.iloc[1,0] = 15.52

# %%
df2.iloc[3,1] = np.nan

# %%
X = df2.iloc[[0,2,4],[0,2]]
y = df2.iloc[[0,2,4],[1]]

lr = LinearRegression()
lr.fit(X.values,y)
lr.predict(df2.iloc[3,[0,2]].values.reshape(1,2))
# Out:
# array([[10.08982036]])

# %%
df2.iloc[3,1] = 10.09

# %%
df2.iloc[4,-1] = np.nan

X = df2.iloc[[0,2,3],0:2]
y = df2.iloc[[0,2,3],-1]

lr = LinearRegression()
lr.fit(X.values,y)
lr.predict(df2.iloc[4,0:2].values.reshape(1,2))
# Out:
# array([-0.90187891])

# %%
df2.iloc[4,-1] = -0.90

# %%
df2
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21       8.00           15.00            30.00
# 37      15.52            5.00            15.52
# 2       15.00           10.00            41.00
# 14      12.00           10.09            26.00
# 44       2.00           15.00            -0.90
